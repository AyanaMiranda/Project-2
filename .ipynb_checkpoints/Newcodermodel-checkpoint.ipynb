# %%
# Import the data
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder




df = pd.read_csv('./clean-data/2017-fCC-New-Coders-Survey-Data.csv')
df.head()
# Out:
# C:\Users\philk\AppData\Local\Temp\ipykernel_79060\422654435.py:11: DtypeWarning: Columns (17,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./clean-data/2017-fCC-New-Coders-Survey-Data.csv')
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# ...

# %%
# Setup X and y variables
X = df.drop(columns='y')
y = df['y'].values.reshape(-1,1)

# Split the data into training and testing sets
# Split the data into training and testing sets
# The function train_test_split randomly divides the dataset into training and testing subsets
# X_train will contain the features for the training set
# X_test will contain the features for the testing set
# y_train will contain the target variable for the training set
# y_test will contain the target variable for the testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=13)
X_train.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Setup X and y variables
# ----> 2 X = df.drop(columns='y')
#       3 y = df['y'].values.reshape(-1,1)
#       5 # Split the data into training and testing sets
#       6 # Split the data into training and testing sets
#       7 # The function train_test_split randomly divides the dataset into training and testing subsets
#    (...)
#      10 # y_train will contain the target variable for the training set
#      11 # y_test will contain the target variable for the testing set
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
# ...

# %% [markdown]
# # Missing Values

# %%
# Find the percentage of null values in each column
X_train.isna().sum()/len(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Find the percentage of null values in each column
# ----> 2 X_train.isna().sum()/len(X_train)
#
# NameError: name 'X_train' is not defined

# %%
# Explore each column with missing values to determine the best fill strategy
# First the job column
X_train['<Choose Column>'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 # Explore each column with missing values to determine the best fill strategy
#       2 # First the job column
# ----> 3 X_train['<Choose Column>'].value_counts()
#
# NameError: name 'X_train' is not defined
